# %% [markdown]
# hiphopTiri

# %% [markdown]
# Tiri wanna be hiphop
# But she is still in grad school
# how to make hiphop Tiri become more academic and polite and pg rate

# %%
import sys
import random

# %%
[line for line in open("Bartier_Cardi.txt")]
# Out:
# ["Bardi in a 'Rari, diamonds all over my body\n",
#  "Shinin' all over my body\n",
#  'Put that bitch on Molly\n',
#  'Bardi\n',
#  'Bitch on Molly\n',
#  '21, diamonds all over my body\n',
#  'Said, I got a bitch on Molly\n',
#  "Ask who nigga, I'm 'bout it\n",
#  'Your bitch wanna party with Cardi\n',
#  "Cartier Bardi in a 'Rari (21)\n",
#  'Diamonds all over my body (Cardi)\n',
#  "Shinin' all over my body (my body)\n",
#  'Cardi got your bitch on molly\n',
#  "Bitch, you ain't gang, you lame\n",
#  'Bentley truck lane to lane\n',
#  'Blow out the brain (21)\n',
#  'I go insane, insane\n',
#  'I drop a check on the chain\n',
#  'Fuck up a check in the plane\n',
#  'Cardi took your man, you upset, uh\n',
#  'Cardi got rich, they upset, yeah\n',
#  'Cardi put the pussy on Offset (Say what?)\n',
#  'Cartier, Cardi B brain on Offset (21)\n',
#  'Cardi took your man, you upset, uh\n',
#  'Cardi got rich, they upset, yeah\n',
#  'Cardi put the pussy on Offset (Cardi)\n',
# ...

# %%
hiphopTiri = [line.strip() for line in open("Bartier_Cardi.txt")]

# %%
hiphopTiriLow = [line.lower() for line in hiphopTiri]

# %%
hiphopTiriLow=[line.replace("cardi", "tiri") for line in hiphopTiriLow]
hiphopTiriLow=[line.replace("bitch", "kid") for line in hiphopTiriLow]
hiphopTiriLow=[line.replace("fuck", "luck") for line in hiphopTiriLow]
hiphopTiriLow=[line.replace("pussy", "mommy") for line in hiphopTiriLow]
hiphopTiriLow=[line.replace("motherfuckin", "motherhuggin") for line in hiphopTiriLow]
hiphopTiriLow=[line.replace("molly", "jelly") for line in hiphopTiriLow]
hiphopTiriLow=[line.replace(",", "") for line in hiphopTiriLow]
hiphopTiriLow=[line.replace("\"", "") for line in hiphopTiriLow]
hiphopTiriLow=[line.replace("'", "") for line in hiphopTiriLow]
hiphopTiriLow=[line.replace("?", "") for line in hiphopTiriLow]
hiphopTiriLow=[line.replace("(", "") for line in hiphopTiriLow]
hiphopTiriLow=[line.replace(")", "") for line in hiphopTiriLow]

# %%
hiphopTiriLow
# Out:
# ['bardi in a rari diamonds all over my body',
#  'shinin all over my body',
#  'put that kid on jelly',
#  'bardi',
#  'kid on jelly',
#  '21 diamonds all over my body',
#  'said i got a kid on jelly',
#  'ask who nigga im bout it',
#  'your kid wanna party with tiri',
#  'cartier bardi in a rari 21',
#  'diamonds all over my body tiri',
#  'shinin all over my body my body',
#  'tiri got your kid on jelly',
#  'kid you aint gang you lame',
#  'bentley truck lane to lane',
#  'blow out the brain 21',
#  'i go insane insane',
#  'i drop a check on the chain',
#  'luck up a check in the plane',
#  'tiri took your man you upset uh',
#  'tiri got rich they upset yeah',
#  'tiri put the mommy on offset say what',
#  'cartier tiri b brain on offset 21',
#  'tiri took your man you upset uh',
#  'tiri got rich they upset yeah',
#  'tiri put the mommy on offset tiri',
#  'cartier tiri b brain on offset tiri',
#  'who get this mothalucker started tiri',
# ...

# %%
random.sample(hiphopTiriLow, len(hiphopTiriLow))
# Out:
# ['cartier tiri b brain on offset tiri',
#  'tiri put the mommy on offset say what',
#  'who get this mothalucker started tiri',
#  'your kid wanna party with tiri',
#  'tiri took your man you upset uh',
#  'your kid wanna party with tiri',
#  'i drop a check on the chain',
#  'blow out the brain 21',
#  'tiri put the mommy on offset tiri',
#  'shinin all over my body my body',
#  'diamonds all over my body tiri',
#  'tiri put the mommy on offset tiri',
#  'tiri got rich they upset yeah',
#  'swap out the trap for the fame',
#  'i keep the pump in the trunk trunk',
#  'i like hot sauce on my chicken on god',
#  'pull up to pop at your crew',
#  'diamonds all over my body tiri',
#  'bentley truck lane to lane',
#  'diamonds all over my body tiri',
#  'cartier bardi in a rari 21',
#  'tiri got rich they upset yeah',
#  'kid you aint gang you lame',
#  'tiri got rich they upset yeah',
#  'i go insane insane',
#  'ice on them carti b cartier frames',
#  'kid if you bad then jump jump',
# ...

# %%
words = line.split();
for line in sys.stdin:
    if not line.strip():
        continue
    else:
        all_lines.append(line)

random.shuffle(hiphopTiriLow)
final_lines = random.sample(hiphopTiriLow, 7)
for item in final_lines:
    print hiphopTiriLow
# Out:
# ['bentley truck lane to lane', 'who you know drip like this', 'i from the motherluckin bronx bronx', 'moonwalkin through your clique', 'who that be fly as a martian tiri', 'cartier bardi in a rari 21', 'cartier tiri b brain on offset 21', 'tiri got rich they upset yeah', 'saint laurent savage in an aston yeah', 'kid you a wannabe tiri', 'diamonds all over my body tiri', '21 diamonds all over my body', 'i drop a check on the chain', 'tiri got your kid on jelly', 'blow out the brain 21', 'swap out the dick for the brain', 'sticky with the kick moonrocks in this shit', 'bardi in a rari diamonds all over my body', 'swap out your kid for your main', 'your kid wanna party with tiri', 'im switchin lanes in the range', 'i keep the pump in the trunk trunk', 'i go insane insane', 'tiri took your man you upset uh', 'your kid wanna party with a savage 21', 'tiri put the mommy on offset say what', 'tiri got rich they upset yeah', 'tiri got your kid on jelly', 'them diamonds gon hit like a kid on 
# ...

# %%
#assignment3 
#RWET class by Allison Parrish
#original songs from Cardi B 
#inspi by Aaron Montoya

import sys
import random

# from PyDictionary import PyDictionary

# dictionary = PyDictionary()
# all_lines = []
[line for line in open("Bartier_Cardi.txt")]

#iterate through every element on the stdin
for line in sys.stdin:
    #.strip is get rid of line
    line = line.strip()
    line = line.lower()
    line = line.replace("cardi", "tiri")
    line = line.replace("bitch", "kid")
    line = line.replace("fuck", "luck")
    line = line.replace("pussy", "mommy") #motherfuckin
    line = line.replace("motherfuckin", "motherhuggin")
    line = line.replace(",", "")
    line = line.replace("\"", "")
    line = line.replace("'", "")
    line = line.replace("?", "")
    line = line.replace("(", "")
    line = line.replace(")", "")

    #split line in a list of the words
    words = line.split();
    for line in sys.stdin:
        if not line.strip():
            continue
        else:
            all_lines.append(line)

    random.shuffle(hiphopTiriLow)
    final_lines = random.sample(hiphopTiriLow, 7)
    for item in final_lines:
        print hiphopTiriLow

    
#     new_line = ""
#     for word in words:
#         if len(dictionary.synonym(word)) > 0:
#             new_line = new_line + " " + dictionary.synonym(word)[0]
#         else:
#             new_line = new_line + " " + word

#     print new_line
